# %% [markdown]
# <a href="https://colab.research.google.com/github/Bornitaadhikari/Machine-Learning/blob/main/Linear_Regression_in_Python_(Irish).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#2.1 Get the file
downloaded = drive.CreateFile({'id':'1wKLQ4-ogFKg6tefpvoLiyz1bG_i_Lu8h'}) # replace the id with id of file you want to access
downloaded.GetContentFile('Iris.csv')

# %%
#3.1 Read file as panda dataframe
import pandas as pd
Irish = pd.read_csv('Iris.csv') 
Irish.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Irish[Irish['SepalWidthCm']>4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa

# %%
Irish[Irish['PetalWidthCm']>1]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
Irish[Irish['PetalWidthCm']>2]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=Irish, hue='Species')
plt.show()

# %%
Irish.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
y=Irish[['SepalLengthCm']]

# %%
x=Irish[['SepalWidthCm']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#     SepalWidthCm
# 90           2.6
# 31           3.4
# 22           3.6
# 73           2.8
# 21           3.7

# %%
x_test.head()
# Out:
#      SepalWidthCm
# 123           2.7
# 98            2.5
# 88            3.0
# 83            2.7
# 126           2.8

# %%
y_train.head()
# Out:
#     SepalLengthCm
# 90            5.5
# 31            5.4
# 22            4.6
# 73            6.1
# 21            5.1

# %%
y_test.head()
# Out:
#      SepalLengthCm
# 123            6.3
# 98             5.1
# 88             5.6
# 83             6.0
# 126            6.2

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      SepalLengthCm
# 123            6.3
# 98             5.1
# 88             5.6
# 83             6.0
# 126            6.2

# %%
y_pred[0:5]
# Out:
# array([[5.94090231],
#        [5.96814849],
#        [5.90003305],
#        [5.94090231],
#        [5.92727922]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.633701082047219

# %%
#model-2

# %%
y=Irish[['SepalLengthCm']]

# %%
x=Irish[['SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.12223622730253807
